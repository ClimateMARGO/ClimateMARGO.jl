# %%
using PyPlot, Statistics

# %%
using DataFrames, CSV

# %%
data_path = "../cmip5_rcp85_gmst.csv"
data = CSV.read(data_path);

years = data[:,2];
gmst = Array(data[:, 3:end]);
gmst[ismissing.(gmst)] .= NaN;

# %%
include("../src/model.jl");
include("../src/diagnostics.jl");
include("../src/plotting.jl");
include("../src/defaults.jl");

# %%
function DICE_EBM(t, F; ζ = [0.098, 3.8/2.9, 0.088, 0.025], physics=nothing, default="DICE-2013r", Δt = nothing)    
    if isnothing(physics)
        if default == "Geoffroy-2013"
            physics = Dict("Δt" => Δt, "Cu" => 7.3, "Cd" => 106., "κ" => 0.73, "B" => 1.13)
        elseif default == "Geoffroy-NoMixing"
            physics = Dict("Δt" => Δt, "Cu" => 7.3, "Cd" => 106., "κ" => 0.0, "B" => 1.13)
        elseif default == "MARGO"
            physics = Dict("Δt" => Δt, "Cu" => 0., "Cd" => 106., "κ" => 0.73, "B" => 1.13)
        elseif default == "DICE-2013r"
            physics = nothing
        elseif default == "DICE-NoMixing"
            physics = nothing
            ζ[3] = 0.
        end
    end
        
    if !isnothing(physics)
        ζ[1] = Δt/physics["Cu"]
        ζ[2] = physics["B"]
        ζ[3] = physics["κ"]
        ζ[4] = physics["κ"]*physics["Δt"]/physics["Cd"]
    end
    
    T = zeros(size(t))
    T_LO = zeros(size(t))
    
    for i = 1:length(model.domain)-1
        if ζ[1] == Inf
            T[i+1] = (F[i] + ζ[3]*T_LO[i]) / (ζ[2] + ζ[3])
        else
            T[i+1] = T[i] + ζ[1]*(F[i] - ζ[2]*T[i] - ζ[3]*(T[i] - T_LO[i]))
        end
        T_LO[i+1] = T_LO[i] + ζ[4]*(T[i] - T_LO[i])
    end
    
    return T
end
# Out:
# DICE_EBM (generic function with 1 method)

# %% [markdown]
# ### Stylized Extended RCP8.5 (ECP8.5) scenario

# %%
Δt = 5.
t = collect(1850.:Δt:3000.)

CO2e = zeros(size(t));
q = zeros(size(t));

# Construct CO2e following RCP8.5 until 2100
# https://www.iiasa.ac.at/web-apps/tnt/RcpDb/dsd?Action=htmlpage&page=compare
CO2e[t .<= 2100] = (280. .+ (1350. - 280.) .* exp.((t .- 2100.)/(37.5)))[t .<= 2100];

# Take derivation to estimate q
q[1:size(t[t .<= 2100][1:end-1], 1)] = diff(CO2e[t .<= 2100])/Δt

# Extend according to ECP85 scenario that has emissions linearly decreasing to zero by 2150.
qmax = q[size(t[t .<= 2100][1:end-1], 1)]
q[(t .>= 2100) .& (t .< 2120)] .= qmax
q[t .>= 2120] = (qmax * (1 .- (t .- 2120.)/(2200. - 2120.)))[t .>= 2120]
q[q .< 0.] .= 0.;

model = ClimateModel(t = t, dt=Δt);
model.economics.baseline_emissions = q/model.physics.r;
model.physics.δT_init = 0.;
model.physics.CO₂_init = 280.;

# %%
figure(figsize=(9,7))

subplot(2,2,3)
for i=1:size(gmst, 2)
    plot(years, gmst[:, i], "C0-", lw=1., alpha=0.1)
end
plot(years, mean(gmst[:, :], dims=2), "C0-")
plot([],[],"C0-", label="CMIP5 RCP8.5")
plot(t, DICE_EBM(t, FCO₂(model)/sec_per_year, default="DICE-2013r"), "C1-", lw=2.5, label="DICE-2013r")
plot(t, DICE_EBM(t, FCO₂(model)/sec_per_year, default="Geoffroy-2013", Δt=Δt), "k--", lw=2.5, label="Geoffroy-2013")
plot(model.domain, δT(model), lw=2.5, "k-", label="MARGO")
xlim(1900, 2100)
ylim([0, 6.])
grid(true)
legend()
ylabel(L"baseline global warming [$^{\circ}$C]")
xlabel("year")

subplot(2,2,4)
plot(t, DICE_EBM(t, FCO₂(model)/sec_per_year, default="DICE-2013r"), "C1-", lw=2.5, label="DICE-2013r")
plot(t, DICE_EBM(t, FCO₂(model)/sec_per_year, default="DICE-NoMixing"), "C1:", lw=2.5, label="DICE-NoMixing")
plot(t, DICE_EBM(t, FCO₂(model)/sec_per_year, default="Geoffroy-2013", Δt=Δt), "k--", lw=2.5, label="Geoffroy-2013")
plot(t, DICE_EBM(t, FCO₂(model)/sec_per_year, default="Geoffroy-NoMixing", Δt=Δt), "k:", lw=2.5, label="Geoffroy-NoMixing")
plot(model.domain, δT(model), lw=2.5, "k-", label="MARGO")

plot([1850, 3000], maximum(FCO₂(model)/sec_per_year)/(3.8/2.9)*[1,1], "C1--", alpha=0.2)
plot([1850, 3000], maximum(FCO₂(model))/B*[1,1], "k--", alpha=0.2)

xlim(1900, 2800)
ylim([0, 11.])
plot([2100, 2100], [0, 11], "C3-")
grid(true)
legend()
ylabel(L"baseline global warming [$^{\circ}$C]")
xlabel("year")

subplot(2,2,2)
plot(model.domain, FCO₂(model)/sec_per_year .+ 0.2, lw=2.5, "k-")
plot([2100, 2100], [0, 14.], "C3-")
ylim([0., 12.5])
xlim(1850, 2250)
grid(true)
ylabel(L"baseline radiative forcing [W/m$^{2}$]")
xlabel("year")

subplot(2,2,1)
plot(model.domain, ppm_to_GtCO2(model.economics.baseline_emissions), "k-", label=L"quasi-ECP8.5 (8.5 W/m$^{2}$ by 2100)")
ylim([0, 500])
xlim(1850, 2250)
grid(true)
legend(loc="upper left")
ylabel(L"baseline emissions [GtCO$_{2e}$ / year]")
xlabel("year")

tight_layout()
savefig("../figures/CMIP5_and_DICE_validation.pdf", dpi=200, bbox_inches="tight")
# Out:
# Figure(PyObject <Figure size 900x700 with 4 Axes>)

# %% [markdown]
# ### Rapid spin-up of geoengineering scenario

# %%
G = zeros(size(t))
G = 0.4 .* exp.(-(t .- 2075).^2 / 20^2)
model.controls.geoeng = G

figure(figsize=(13,4.))
subplot(1,3,1)
plot(model.domain, FCO₂_baseline(model)/sec_per_year .+ 0.2, lw=2.5, "k-", label="quasi-ECP8.5")
plot(model.domain, FCO₂(model)/sec_per_year .+ 0.2, lw=2.5, "C3-", label="quasi-ECP8.5 + solar geoengineering")
ylim([0., 11.])
xlim(2000, 2200)
grid(true)
ylabel(L"radiative forcing [W/m$^{2}$]")
xlabel("year")
legend()

subplot(1,3,2)
plot(t, DICE_EBM(t, FCO₂(model)/sec_per_year, default="DICE-2013r"), "C1-", lw=2.5, label="DICE-2013r")
plot(model.domain, δT(model), lw=2.5, "k-", label="MARGO")
plot(t, DICE_EBM(t, FCO₂_baseline(model)/sec_per_year, default="DICE-2013r"), "C1-", lw=2.5, alpha=0.2)
plot(model.domain, δT_baseline(model), lw=2.5, "k-", alpha=0.2)
plot([], [], "k-", alpha=0.2, label="ECP8.5 baseline")
xlim(2000, 2200)
ylim([0, 6.])
grid(true)
legend()
ylabel(L"global warming (w/ short-term solar-geo) [$^{\circ}$C]")
xlabel("year")

subplot(1,3,3)
plot(
    t,
    DICE_EBM(t, FCO₂(model)/sec_per_year, default="DICE-2013r") .-
    DICE_EBM(t, FCO₂_baseline(model)/sec_per_year, default="DICE-2013r"),
    "C1-", lw=2.5, label="DICE-2013r"
)
plot(
    t,
    DICE_EBM(t, FCO₂(model)/sec_per_year, default="DICE-NoMixing") .-
    DICE_EBM(t, FCO₂_baseline(model)/sec_per_year, default="DICE-NoMixing"),
    "C1--", lw=2.5, label="DICE-NoMixing"
)
plot(model.domain, δT(model) .- δT_baseline(model), lw=2.5, "k-", label="MARGO")
plot(
    t,
    DICE_EBM(t, FCO₂(model)/sec_per_year, default="Geoffroy-2013", Δt=Δt) .-
    DICE_EBM(t, FCO₂_baseline(model)/sec_per_year, default="Geoffroy-2013", Δt=Δt),
    "k--", lw=2.5, label="Geoffroy-2013"
)
xlim(2000, 2200)
ylim([-2, 0.])
grid(true)
legend()
ylabel(L"cooling by solar-geoengineering [$^{\circ}$C]")
xlabel("year")

tight_layout()
savefig("../figures/DICE_geoengineering_bias.pdf", dpi=200, bbox_inches="tight")
# Out:
# Figure(PyObject <Figure size 1300x400 with 3 Axes>)
